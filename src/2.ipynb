# %%
import pandas as pd
import matplotlib.pyplot as plt

dataAnggur = pd.read_csv('../data/anggur.csv')

# %% [markdown]
# Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap
# kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot
# tersebut.

# %% [markdown]
# ### 1. fixed acidity

# %%
# Data
data = dataAnggur['fixed acidity']

# %%
# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Fixed Acidity in Wine')
plt.xlabel('Fixed Acidity')
plt.ylabel('Frequency')

# Show graph
plt.show()

# %% [markdown]
# Histogram menunjukkan distribusi nilai *fixed acidity* atau nilai keasaman tetap dalam 1000 sampel anggur. Distribusi tersebut memiliki bentuk *bell-shaped* yang simetris dan memiliki nilai puncak pada 7,5. Rentang nilai berkisar antara 3,0 hingga 11,5. Ada beberapa yang memiliki nilai *fixed acidity* yang sangat rendah ataupun sangat tinggi tetapi tidak mempengaruhi bentuk keseluruhan distribusi.

# %%
# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Fixed Acidity in Wine')
plt.ylabel('Fixed Acidity')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Boxplot menunjukkan nilai minimum dari *fixed acidity* adalah sekitar 4, sedangkan nilai maksimumnya sekitar 10,5. Walaupun begitu, terdapat lima *outlier*, tiga diantaranya berada dibawah nilai minimum. Nilai median terletak pada sekitar 7, dengan *interquartile range* sebesar 6,5 sampai 8.

# %% [markdown]
# ### 2. volatile activity

# %%
# Data
data = dataAnggur['volatile acidity']

# %%
# ======= Histogram ============
plt.hist(data, color='red')

# Set attributes
plt.title('Distribution of Volatile Acidity in Wine')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')

# Show graph
plt.show()

# %% [markdown]
# Histogram menunjukkan distribusi nilai *Volatile Acidity* dalam sampel 1000 anggur.

# %%
# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Volatile Acidity in Wine')
plt.ylabel('Volatile Acidity')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 3. citric acid

# %%
# Data
data = dataAnggur['citric acid']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Citric Acid in Wine')
plt.xlabel('Citric Acid')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Citric Acid in Wine')
plt.ylabel('Citric Acid')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 4. residual sugar

# %%
# Data
data = dataAnggur['residual sugar']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Residual Sugar in Wine')
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Residual Sugar in Wine')
plt.ylabel('Residual Sugar')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 5. chlorides

# %%
# Data
data = dataAnggur['chlorides']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Clorides in Wine')
plt.xlabel('Clorides')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Clorides in Wine')
plt.ylabel('Clorides')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 6. free sulfur dioxide

# %%
# Data
data = dataAnggur['free sulfur dioxide']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Free Sulfur Dioxide in Wine')
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Free Sulfur Dioxide in Wine')
plt.ylabel('Free Sulfur Dioxide')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 7. total sulfur dioxide

# %%
# Data
data = dataAnggur['total sulfur dioxide']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Total Sulfur Dioxide in Wine')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Total Sulfur Dioxide in Wine')
plt.ylabel('Total Sulfur Dioxide')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 8. density

# %%
# Data
data = dataAnggur['density']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Density in Wine')
plt.xlabel('Density')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Density in Wine')
plt.ylabel('Density')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 9. pH

# %%
# Data
data = dataAnggur['pH']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of pH in Wine')
plt.xlabel('pH')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of pH in Wine')
plt.ylabel('pH')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 10. sulphates

# %%
# Data
data = dataAnggur['sulphates']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Sulphates in Wine')
plt.xlabel('Sulphates')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Sulphates in Wine')
plt.ylabel('Sulphates')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 11. alcohol

# %%
# Data
data = dataAnggur['alcohol']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Alcohol in Wine')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Alcohol in Wine')
plt.ylabel('Alcohol')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...

# %% [markdown]
# ### 12. quality

# %%
# Data
data = dataAnggur['quality']

# ======= Histogram ============
plt.hist(data, color='lightblue')

# Set attributes
plt.title('Distribution of Quality in Wine')
plt.xlabel('Quality')
plt.ylabel('Frequency')

# Show graph
plt.show()


# ======= Boxplot ============
plt.boxplot(data)

# Set attributes
plt.title('Distribution of Quality in Wine')
plt.ylabel('Quality')
plt.xticks([],[])

# Show graph
plt.show()

# %% [markdown]
# Berdasarkan visualisasi di atas, ...
